# %%
# based on https://raw.githubusercontent.com/keras-team/keras/master/examples/mnist_cnn.py

# %%
'''Trains a simple convnet on the MNIST dataset.

Gets to 99.25% test accuracy after 12 epochs
(there is still a lot of margin for parameter tuning).
16 seconds per epoch on a GRID K520 GPU.
'''
# Out:
# 'Trains a simple convnet on the MNIST dataset.\n\nGets to 99.25% test accuracy after 12 epochs\n(there is still a lot of margin for parameter tuning).\n16 seconds per epoch on a GRID K520 GPU.\n'

# %%
from __future__ import print_function
import keras
from keras.datasets import mnist, fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

from sklearn.model_selection import train_test_split

# %%
batch_size = 128
num_classes = 10
epochs = 12

# input image dimensions
img_rows, img_cols = 28, 28

# check points
checkpoint_path = 'minist-cnn/e-{epoch:04d}.ckpt'
checkpoint_dir = os.path.dirname(checkpoint_path)

# fix random seeds
from numpy.random import seed
seed(3)
from tensorflow import set_random_seed
set_random_seed(31)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-286-e02929e296eb> in <module>
#       8 # check points
#       9 checkpoint_path = 'minist-cnn/models.ckpt'
# ---> 10 checkpoint_dir = os.path.dirname(checkpoint_path)
#      11
#      12 # fix random seeds
#
# NameError: name 'os' is not defined

# %%
# the data, split between train and test sets
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

y_label = y_test.copy()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)

# %%
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

'''x_train, x_vali, y_train, y_vali = train_test_split(x_train,
                                                    y_train,
                                                    test_size=0.2,
                                                    random_state=42)
'''
# Out:
# 'x_train, x_vali, y_train, y_vali = train_test_split(x_train,\n                                                    y_train,\n                                                    test_size=0.2,\n                                                    random_state=42)\n'

# %%
# call back function to save the models
cp_callback = keras.callbacks.ModelCheckpoint(checkpoint_path,
                                              verbose=1,
                                              period=1)

# %%
model = Sequential([
    Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(rate = 1 - 0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(rate = 1 - 0.5),
    Dense(num_classes, activation='softmax')
])

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
history = model.fit(x_test, y_test,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_split=0.2,
          callbacks = [cp_callback])
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/12
# 8000/8000 [==============================] - 13s 2ms/step - loss: 1.1080 - acc: 0.6114 - val_loss: 0.6235 - val_acc: 0.7730
#
# Epoch 00001: saving model to minist-cnn/models.ckpt
# Epoch 2/12
# 8000/8000 [==============================] - 13s 2ms/step - loss: 0.6790 - acc: 0.7540 - val_loss: 0.5209 - val_acc: 0.8015
#
# Epoch 00002: saving model to minist-cnn/models.ckpt
# Epoch 3/12
# 8000/8000 [==============================] - 12s 2ms/step - loss: 0.5868 - acc: 0.7926 - val_loss: 0.4770 - val_acc: 0.8290
#
# Epoch 00003: saving model to minist-cnn/models.ckpt
# Epoch 4/12
# 1920/8000 [======>.......................] - ETA: 9s - loss: 0.5501 - acc: 0.8016
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-292-947721774351> in <module>
#       4           verbose=1,
# ...

# %%
score = model.evaluate(x_test, y_test, verbose=0)

# %%
print(score)
# Out:
# [0.3433068900823593, 0.8774]

# %%
y_pred = model.predict(x_test)

# %%
y_label.shape
# Out:
# (10000,)

# %%
import matplotlib.colors as colors
tableau10 = colors.ListedColormap(["#4E79A7", "#F28E2B", "#E15759", "#76B7B2", "#59A14F", 
                                   "#EDC948", "#B07AA1", "#FF9DA7", "#9C755F", "#BAB0AC"])

# %%
from sklearn import cluster, datasets
from mpl_toolkits.mplot3d import Axes3D
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import decomposition
x_reformatted = x_test.reshape(10000, 784)

# %%
pca_test = decomposition.PCA(n_components=3)
x_test_pca = pca_test.fit_transform(x_reformatted)

pca_pred = decomposition.PCA(n_components=3)
y_pred_pca = pca_test.fit_transform(y_pred)

# %%
fig = plt.figure(figsize=(15, 7))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(xs = x_test_pca[:,0], ys = x_test_pca[:,1], zs = x_test_pca[:,2], c = y_label, cmap = tableau10, alpha = 1)
plt.title('PCA 3D before training')

fig.add_subplot(1, 2, 2)
plt.scatter(x = x_test_pca[:,0], y = x_test_pca[:,1], c = y_label, cmap = tableau10, alpha= 1)
plt.title('PCA 2D before training')
# Out:
# Text(0.5, 1.0, 'PCA 2D before training')

# %%
fig = plt.figure(figsize=(15, 7))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(xs = y_pred_pca[:,0], ys = y_pred_pca[:,1], zs = y_pred_pca[:,2], c = y_label, alpha = 1, cmap = tableau10)
plt.title('PCA 3D after training')

fig.add_subplot(1, 2, 2)
plt.scatter(x = y_pred_pca[:,0], y = y_pred_pca[:,1], c = y_label, alpha= 1, cmap = tableau10)
plt.title('PCA 2D after training')
# Out:
# Text(0.5, 1.0, 'PCA 2D after training')

# %%
x_test_small = x_reformatted[2000:4000]
y_pred_small = y_pred[2000:4000]
y_label_small = y_label[2000:4000]

# %%
from sklearn.manifold import TSNE,Isomap
tsne2 = TSNE(n_components=2, n_iter=1000)
tsne3 = TSNE(n_components=3, n_iter=2000, perplexity=40)

# %%
x_test_tsne2 = tsne2.fit_transform(x_test_small)
x_test_tsne3 = tsne3.fit_transform(x_test_small)

y_pred_tsne2 = tsne2.fit_transform(y_pred_small)
y_pred_tsne3 = tsne3.fit_transform(y_pred_small)

# %%
import statistics, math, numbers, numpy

x_test_tsne2_ = x_test_tsne2.transpose()
x_test_tsne2_ = numpy.array([[(d - numpy.mean(d))/ numpy.std(d)] for d in x_test_tsne2_]).reshape(2, 2000).transpose()

x_test_tsne3_ = x_test_tsne3.transpose()
x_test_tsne3_ = numpy.array([[(d - numpy.mean(d))/ numpy.std(d)] for d in x_test_tsne3_]).reshape(3, 2000).transpose()

# %%
y_pred_tsne2_ = y_pred_tsne2.transpose()
y_pred_tsne2_ = numpy.array([[(d - numpy.mean(d))/ numpy.std(d)] for d in y_pred_tsne2_]).reshape(2, 2000).transpose()

y_pred_tsne3_ = y_pred_tsne3.transpose()
y_pred_tsne3_ = numpy.array([[(d - numpy.mean(d))/ numpy.std(d)] for d in y_pred_tsne3_]).reshape(3, 2000).transpose()

# %%
fig = plt.figure(figsize=(15, 7))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(xs = x_test_tsne3_[:,0], ys =x_test_tsne3_[:,1], zs = x_test_tsne3_[:,2], c = y_label_small, cmap = tableau10, alpha = 1)
plt.title('t-SNE 3D before training')

fig.add_subplot(1, 2, 2)
plt.scatter(x = x_test_tsne2_[:,0], y = x_test_tsne2_[:,1], c = y_label_small, cmap = tableau10, alpha= 1)
plt.title('t-SNE 2D before training')
# Out:
# Text(0.5, 1.0, 't-SNE 2D before training')

# %%
import sklearn as sk

fig = plt.figure(figsize=(15, 7))

ax = fig.add_subplot(1, 2, 1, projection='3d')
ax.scatter(xs = y_pred_tsne3_[:,0], ys = y_pred_tsne3_[:,1], zs = y_pred_tsne3_[:,2], cmap = tableau10, c = y_label_small, alpha = 1)
plt.title('t-SNE 3D after training')
ax.view_init(0, 0)

fig.add_subplot(1, 2, 2)
plt.scatter(x = y_pred_tsne2_[:,0], y = y_pred_tsne2_[:,1], c = y_label_small, cmap = tableau10, alpha= 1, s = 35)
plt.margins(x = 0.5, y = 0.5)
plt.title('t-SNE 2D after training')
# Out:
# Text(0.5, 1.0, 't-SNE 2D after training')
